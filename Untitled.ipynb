# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')

# %%
df_test = pd.read_csv('test.csv')

# %%
df_train
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0          0               0.0         No                      6.0
# 1          1               1.0         No                      7.0
# 2          2               6.0        Yes                      1.0
# 3          3               3.0         No                      7.0
# 4          4               1.0         No                      4.0
# ...      ...               ...        ...                      ...
# 18519  18519               3.0         No                      7.0
# 18520  18520               1.0        NaN                      6.0
# 18521  18521               7.0        Yes                      1.0
# 18522  18522               NaN        Yes                      1.0
# 18523  18523               1.0         No                      8.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 0                4.0                        No                 15.0
# ...

# %%
df_test
# Out:
#          id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0     18524               3.0         No                      7.0
# 1     18525               NaN        Yes                      0.0
# 2     18526               3.0         No                      5.0
# 3     18527               3.0         No                      4.0
# 4     18528               9.0        Yes                      1.0
# ...     ...               ...        ...                      ...
# 6170  24694               3.0         No                      5.0
# 6171  24695               8.0        Yes                      2.0
# 6172  24696               2.0         No                      4.0
# 6173  24697               3.0         No                      4.0
# 6174  24698               NaN        Yes                      1.0
#
#       Going_outside Drained_after_socializing  Friends_circle_size  \
# 0               4.0                        No                  6.0
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  object
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  object
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
df_train.isna().sum()
# Out:
# id                              0
# Time_spent_Alone             1190
# Stage_fear                   1893
# Social_event_attendance      1180
# Going_outside                1466
# Drained_after_socializing    1149
# Friends_circle_size          1054
# Post_frequency               1264
# Personality                     0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# id                             0
# Time_spent_Alone             425
# Stage_fear                   598
# Social_event_attendance      397
# Going_outside                466
# Drained_after_socializing    432
# Friends_circle_size          350
# Post_frequency               408
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  object
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  object
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
df_train.isna().sum()
# Out:
# id                              0
# Time_spent_Alone             1190
# Stage_fear                   1893
# Social_event_attendance      1180
# Going_outside                1466
# Drained_after_socializing    1149
# Friends_circle_size          1054
# Post_frequency               1264
# Personality                     0
# dtype: int64

# %%
df_train['Time_spent_Alone'] = df_train['Time_spent_Alone'].median()

# %%
df_test['Time_spent_Alone'] = df_test['Time_spent_Alone'].median()

# %%
df_train['Social_event_attendance'] = df_train['Social_event_attendance'].median()
df_test['Social_event_attendance'] = df_test['Social_event_attendance'].median()

# %%
df_train['Going_outside'] = df_train['Going_outside'].median()
df_test['Going_outside'] = df_test['Going_outside'].median()

# %%
df_train['Friends_circle_size'] = df_train['Friends_circle_size'].median()
df_test['Friends_circle_size'] = df_test['Friends_circle_size'].median()

# %%
df_train['Post_frequency'] = df_train['Post_frequency'].median()
df_test['Post_frequency'] = df_test['Post_frequency'].median()

# %%
df_train.isna().sum()
# Out:
# id                              0
# Time_spent_Alone                0
# Stage_fear                   1893
# Social_event_attendance         0
# Going_outside                   0
# Drained_after_socializing    1149
# Friends_circle_size             0
# Post_frequency                  0
# Personality                     0
# dtype: int64

# %%
df_train['Stage_fear'].value_counts()
# Out:
# Stage_fear
# No     12609
# Yes     4022
# Name: count, dtype: int64

# %%
df_test['Stage_fear'] = df_test['Stage_fear'].fillna(np.random.choice(a = ['Yes','No'], p = [0.5,0.5]))
df_train['Stage_fear'] = df_train['Stage_fear'].fillna(np.random.choice(a = ['Yes','No'], p = [0.5,0.5]))

# %%
df_train.isna().sum()
# Out:
# id                              0
# Time_spent_Alone                0
# Stage_fear                      0
# Social_event_attendance         0
# Going_outside                   0
# Drained_after_socializing    1149
# Friends_circle_size             0
# Post_frequency                  0
# Personality                     0
# dtype: int64

# %%
df_train['Drained_after_socializing'].value_counts()
# Out:
# Drained_after_socializing
# No     13313
# Yes     4062
# Name: count, dtype: int64

# %%
df_test['Drained_after_socializing'] = df_test['Drained_after_socializing'].fillna(np.random.choice(a = ['Yes','No'], p = [0.5,0.5]))
df_train['Drained_after_socializing'] = df_train['Drained_after_socializing'].fillna(np.random.choice(a = ['Yes','No'], p = [0.5,0.5]))

# %%
df_train.isna().sum()
# Out:
# id                           0
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# id                           0
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           18524 non-null  float64
#  2   Stage_fear                 18524 non-null  object
#  3   Social_event_attendance    18524 non-null  float64
#  4   Going_outside              18524 non-null  float64
#  5   Drained_after_socializing  18524 non-null  object
#  6   Friends_circle_size        18524 non-null  float64
#  7   Post_frequency             18524 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
df_train['Stage_fear'] = label.fit_transform(df_train['Stage_fear'])
df_test['Stage_fear'] = label.transform(df_test['Stage_fear'])

# %%
df_train['Drained_after_socializing'] = label.fit_transform(df_train['Drained_after_socializing'])
df_test['Drained_after_socializing'] = label.transform(df_test['Drained_after_socializing'])

# %%
df_train['Personality'] = label.fit_transform(df_train['Personality'])

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           18524 non-null  float64
#  2   Stage_fear                 18524 non-null  int64
#  3   Social_event_attendance    18524 non-null  float64
#  4   Going_outside              18524 non-null  float64
#  5   Drained_after_socializing  18524 non-null  int64
#  6   Friends_circle_size        18524 non-null  float64
#  7   Post_frequency             18524 non-null  float64
#  8   Personality                18524 non-null  int64
# dtypes: float64(5), int64(4)
# memory usage: 1.3 MB

# %%
from xgboost import XGBClassifier
import xgboost as xgb

# %%
model = XGBClassifier(
    n_estimators=500,        
    learning_rate=0.05,      
    max_depth=6,             
    subsample=0.8,           
    colsample_bytree=0.8,    
    gamma=1,                
    reg_alpha=0.1,           
    reg_lambda=1,            
    use_label_encoder=False, 
    eval_metric='logloss',   
    random_state=42,
    n_jobs=-1                
)

# %%
df_train = df_train.drop('id',axis = 1)
df_test = df_test.drop('id',axis = 1)

# %%
X_train = df_train.drop('Personality',axis = 1)
y_train = df_train['Personality']
X_test = df_test.copy()

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\Boris\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\training.py:183: UserWarning: [14:34:33] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=1,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
import xgboost as xgb
xgb.plot_importance(model, max_num_features=10); plt.show()

# %%
y_pred = model.predict(X_test)

# %%
sub = pd.read_csv('sample_submission.csv')

# %%
sub["Personality"] = sub["Personality"].map({1: "Extrovert", 0: "Introvert"})

# %%
sub['Personality'] = y_pred

# %%
sub.to_csv('sub.csv',index=False)
